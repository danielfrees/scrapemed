# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.insert(0, "../../scrapemed")

import scrapemed.paper as paper
import scrapemed.scrape as scrape
from scrapemed.paperSet import paperSet
import pandas as pd
import lxml
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# True

# %%
EMAIL = os.getenv("PMC_EMAIL")
pset = paperSet.from_search(EMAIL, term = "brain[ti] AND surgery[ti]", retmax = 11)
# Out:
# Generating paperSet from search (This can take a while due to PMC HTTP Request Limitations!)...
# Done generating paperSet!

# %%
pset[0].title
# Out:
# 'Perioperative brain injury marker concentrations in neonatal open-heart surgery: a prospective observational study'

# %%
pset.add_pmcids(pmcids= [7067710, 7067711], email = EMAIL)
# Out:
# 2

# %%
pset.df
# Out:
#        PMCID  Last_Updated                                              Title  \
# 0   10445649  (9, 8, 2023)  Perioperative brain injury marker concentratio...
# 1    9889004  (9, 8, 2023)                               Surgery of the Brain
# 2    9888923  (9, 8, 2023)                                      Brain Surgery
# 3   10423256  (9, 8, 2023)  A 3-month survival model after Gamma Knife sur...
# 4   10417431  (9, 8, 2023)  Surgery vs. Radiosurgery for Patients with Loc...
# 5   10414059  (9, 8, 2023)  Feasibility of comparing medical management an...
# 6   10410636  (9, 8, 2023)  Comparison of peripheral blood saturation with...
# 7   10406254  (9, 8, 2023)  White matter tract changes in pediatric poster...
# 8   10402651  (9, 8, 2023)  Anesthetic Management of a Patient With Parkin...
# 9   10372448  (9, 8, 2023)  Large-scale brain networks and intra-axial tum...
# 10  10371730  (9, 8, 2023)  Retracted: Analysis of the Factors Related to ...
# 11   7067710  (9, 8, 2023)  Phase I Pharmacokinetic Study of Fixed-Dose Co...
# 12   7067711  (9, 8, 2023)  Decline and diversity in Swedish seas: Environ...
#
#                                               Authors  \
# 0   [Åsa Jungner, Finn Lennartsson, Isabella Björk...
# 1                                                None
# 2                                                None
# 3   [Hangeul Park, Hyun-Tai Chung, Jin-Wook Kim, Y...
# 4   [Giorgio Fiore, Leonardo Tariciotti, Giulio An...
# 5   [James J M Loan, Andrew Bacon, Janneke van Bei...
# 6   [Bartosz Kubisa, Anna Lesińska, Krzysztof Safr...
# 7   [Jeffrey Tanedo, Niharika Gajawelli, Sharon Gu...
# 8                                      [Zainub Jooma]
# 9   [Timothy F. Boerger, Peter Pahapill, Alissa M....
# 10               [Contrast Media & Molecular Imaging]
# 11  [Sanela Tarabar, Debra Kelsh, Bradley Vince, R...
# 12  [Susanna Lidström, Sverker Sörlin, Henrik Sved...
#
#                               Non_Author_Contributors  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                 [Axel H. Schönthal]
# 5   [Ioannis Fouyas, Allan MacRaild, Jessica Teasd...
# 6                                                None
# 7                                                None
# 8                  [Alexander Muacevic, John R Adler]
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
#
#                                              Abstract  \
# 0   \nNeonates with critical congenital heart defe...
# 1
# 2
# 3   \nGamma Knife surgery (GKS) for brain metastas...
# 4   \nSECTION: Simple Summary:\n\nWith an incidenc...
# 5   \nSECTION: Introduction:\n\nThe top research p...
# 6   \nSECTION: Introduction:\n\nNear-infrared spec...
# 7   \nSECTION: Background:\n\nSurvivors of pediatr...
# 8   \nParkinson’s disease (PD) is a common neurode...
# 9   \nIn recent years, a paradigm shift in neurosc...
# 10
# 11  \nSECTION: Introduction:\n\nA fixed-dose combi...
# 12  \nBefore the mid-twentieth century, there was ...
#
#                                                  Body  \
# 0   \nSECTION: Introduction:\n\nNeonates with crit...
# 1
# 2
# 3   \nSECTION: Introduction:\n\nStereotactic radio...
# 4   \nSECTION: 1. Introduction:\n\nWith an inciden...
# 5   \nSECTION: Introduction:\n\nSymptomatic brain ...
# 6   \nSECTION: Introduction:\n\nDuring thoracic su...
# 7   \nSECTION: Introduction:\n\nCentral nervous sy...
# 8   \nSECTION: Introduction:\n\nParkinson’s diseas...
# 9   \nSECTION: 1. Introduction:\n\nTraditionally, ...
# 10  \nThis article has been retracted by Hindawi f...
# 11  \nSECTION: Key Points:\n\n\n\nSECTION: Introdu...
# 12  \nSECTION: Introduction: A narrative of declin...
#
#                                            Journal_ID  \
# 0   {'nlm-ta': 'Front Pediatr', 'iso-abbrev': 'Fro...
# 1   {'nlm-ta': 'Chic Med J Exam', 'pmc': 'chicmedj...
# 2   {'nlm-ta': 'Chic Med J Exam', 'pmc': 'chicmedj...
# 3      {'nlm-ta': 'Sci Rep', 'iso-abbrev': 'Sci Rep'}
# 4   {'nlm-ta': 'Cancers (Basel)', 'iso-abbrev': 'C...
# 5   {'nlm-ta': 'BMJ Open', 'iso-abbrev': 'BMJ Open...
# 6   {'nlm-ta': 'Kardiochir Torakochirurgia Pol', '...
# 7   {'nlm-ta': 'Front Neuroimaging', 'iso-abbrev':...
# 8   {'nlm-ta': 'Cureus', 'iso-abbrev': 'Cureus', '...
# 9   {'nlm-ta': 'Front Hum Neurosci', 'iso-abbrev':...
# 10  {'nlm-ta': 'Contrast Media Mol Imaging', 'iso-...
# 11  {'nlm-ta': 'Drugs R D', 'iso-abbrev': 'Drugs R...
# 12         {'nlm-ta': 'Ambio', 'iso-abbrev': 'Ambio'}
#
#                                         Journal_Title  \
# 0                             Frontiers in Pediatrics
# 1            The Chicago Medical Journal and Examiner
# 2            The Chicago Medical Journal and Examiner
# 3                                  Scientific Reports
# 4                                             Cancers
# 5                                            BMJ Open
# 6   Kardiochirurgia i Torakochirurgia Polska = Pol...
# 7                           Frontiers in Neuroimaging
# 8                                              Cureus
# 9                     Frontiers in Human Neuroscience
# 10                 Contrast Media & Molecular Imaging
# 11                                       Drugs in R&D
# 12                                              Ambio
#
#                                           ISSN  ...        License  \
# 0                        {'epub': '2296-2360'}  ...  Not Specified
# 1                                           {}  ...  Not Specified
# 2                                           {}  ...  Not Specified
# 3                        {'epub': '2045-2322'}  ...  Not Specified
# 4                        {'epub': '2072-6694'}  ...  Not Specified
# 5                        {'epub': '2044-6055'}  ...  Not Specified
# 6   {'ppub': '1731-5530', 'epub': '1897-4252'}  ...  Not Specified
# 7                        {'epub': '2813-1193'}  ...  Not Specified
# 8                        {'epub': '2168-8184'}  ...  Not Specified
# 9                        {'epub': '1662-5161'}  ...  Not Specified
# 10  {'ppub': '1555-4309', 'epub': '1555-4317'}  ...  Not Specified
# 11  {'ppub': '1174-5886', 'epub': '1179-6901'}  ...     OpenAccess
# 12  {'ppub': '0044-7447', 'epub': '1654-7209'}  ...     OpenAccess
#
#                                               Funding  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                  [Technology Planning & Evaluation]
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                       [Pfizer Consumer Healthcare]
# 12  [The Swedish Research Council, European Resear...
#
#                                              Footnote  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3   Publisher's note - Springer Nature remains neu...
# 4   Disclaimer/Publisher’s Note: The statements, o...
# 5   Twitter: @James_JM_Loan, @bullen_ali, @Bleedin...
# 6                                                None
# 7                                                None
# 8   Consent was obtained or waived by all particip...
# 9                                                None
# 10                                               None
# 11  The authors David E. Kellstein, Suzanne Meeves...
# 12  Publisher's Note - Springer Nature remains neu...
#
#                                      Acknowledgements  \
# 0   [Acknowledgments \n       The authors wish to ...
# 1                                                  []
# 2                                                  []
# 3   [Acknowledgements \n       The authors appreci...
# 4                                                  []
# 5   [We thank all members of the Patient, carer an...
# 6                                                  []
# 7   [The authors would like to thank the families ...
# 8                                                  []
# 9                                                  []
# 10                                                 []
# 11  [Acknowledgements \n       Medical writing sup...
# 12  [Acknowledgements \n       Open access funding...
#
#                                                 Notes  \
# 0                                                  []
# 1                                                  []
# 2                                                  []
# 3   [Title: Author contributions\nE.J.L. contribut...
# 4   [Title: Author Contributions\nConceptualizatio...
# 5                                                  []
# 6                                                  []
# 7                                                  []
# 8                                                [\n]
# 9                                                  []
# 10                                                 []
# 11  [Title: Author Contributions\nStudy design: Al...
# 12                                                 []
#
#                                           Custom_Meta  \
# 0   {'section-at-acceptance': 'Pediatric Critical ...
# 1                                                None
# 2                                                None
# 3   {'issue-copyright-statement': '© Springer Natu...
# 4                                                None
# 5                     {'special-feature': 'unlocked'}
# 6                                                None
# 7                                                None
# 8                                                None
# 9   {'section-at-acceptance': 'Brain Imaging and S...
# 10                                               None
# 11  {'issue-copyright-statement': '© The Author(s)...
# 12  {'issue-copyright-statement': '© Royal Swedish...
#
#                                               Ref_Map  \
# 0   {0: {'Authors': ['R Liamlahi', 'B Latal'], 'Ti...
# 1                                                  {}
# 2                                                  {}
# 3   {0: {'Authors': ['G Bowden'], 'Title': 'Gamma ...
# 4   {0: {'Authors': ['L. Nayak', 'E.Q. Lee', 'P.Y....
# 5   {0: '
# ', 1: '
# ', 2: '
# ', 4: {'Label': 'Figure ...
# 6   {0: '. ', 1: '. ', 2: '. ', 3: '. ', 4: <panda...
# 7   {0: {'Authors': ['Y. T. Udaka'], 'Title': 'Ped...
# 8   {0: {'Authors': [], 'Title': 'Parkinson's dise...
# 9   {0: {'Authors': ['K. Burchiel', 'H. Clarke', '...
# 10  {0: {'Authors': ['W. Chen', 'D. Sheng'], 'Titl...
# 11  {0:                                           ...
# 12  {0: 'Awebro, K. 2008. Ett bottennapp för Sveri...
#
#                                             Citations  \
# 0   [Authors: ['R Liamlahi', 'B Latal']; Title: No...
# 1                                                  []
# 2                                                  []
# 3   [Authors: ['G Bowden']; Title: Gamma knife rad...
# 4   [Authors: ['L. Nayak', 'E.Q. Lee', 'P.Y. Wen']...
# 5                                                  []
# 6                                                  []
# 7   [Authors: ['Y. T. Udaka']; Title: Pediatric br...
# 8   [Authors: []; Title: Parkinson's disease; Sour...
# 9   [Authors: ['K. Burchiel', 'H. Clarke', 'G. Oje...
# 10  [Authors: ['W. Chen', 'D. Sheng']; Title: Anal...
# 11  [Authors: ['A Dickman']; Title: Choosing over-...
# 12  [Authors: ['E Hagen', 'R Feistel']; Title: Cli...
#
#                                                Tables  \
# 0   [<style type="text/css">\n</style>\n<table id=...
# 1                                                  []
# 2                                                  []
# 3   [<style type="text/css">\n</style>\n<table id=...
# 4                                                  []
# 5   [<style type="text/css">\n</style>\n<table id=...
# 6   [<style type="text/css">\n</style>\n<table id=...
# 7   [<style type="text/css">\n</style>\n<table id=...
# 8                                                  []
# 9   [<style type="text/css">\n</style>\n<table id=...
# 10                                                 []
# 11  [<table border="1" class="dataframe">\n  <thea...
# 12                                                 []
#
#                                               Figures
# 0   [{'Label': 'Figure 1', 'Caption': '
#           ...
# 1                                                  []
# 2                                                  []
# 3   [{'Label': 'Figure 1', 'Caption': 'Kaplan‒Meie...
# 4   [{'Label': 'Figure 1', 'Caption': '
#         Fl...
# 5   [{'Label': 'Figure 1', 'Caption': '
#           ...
# 6   [{'Label': 'Figure 1', 'Caption': '
#           ...
# 7   [{'Label': 'Figure 1', 'Caption': '
#           ...
# 8   [{'Label': 'Figure 1', 'Caption': '
#           ...
# 9   [{'Label': 'FIGURE 1', 'Caption': '
#           ...
# 10                                                 []
# 11  [{'Label': 'Fig. 1', 'Caption': 'Median plasma...
# 12                                                 []
#
# [13 rows x 31 columns]

# %%
pset.df.columns
# Out:
# Index(['PMCID', 'Last_Updated', 'Title', 'Authors', 'Non_Author_Contributors',
#        'Abstract', 'Body', 'Journal_ID', 'Journal_Title', 'ISSN',
#        'Publisher_Name', 'Publisher_Location', 'Article_ID', 'Article_Types',
#        'Article_Categories', 'Published_Date', 'Volume', 'Issue', 'First_Page',
#        'Last_Page', 'Copyright', 'License', 'Funding', 'Footnote',
#        'Acknowledgements', 'Notes', 'Custom_Meta', 'Ref_Map', 'Citations',
#        'Tables', 'Figures'],
#       dtype='object')

# %%
pset.visualize()
# Out:
# MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.

# %%
pset2 = paperSet.from_pmcid_list([7067710, 7067711], EMAIL)
# Out:
# Generating paperSet from PMCID list (This can take a while due to PMC HTTP Request Limitations!)...
# Done generating paperSet!

# %%
pset2.df
# Out:
#      PMCID  Last_Updated                                              Title  \
# 0  7067710  (9, 8, 2023)  Phase I Pharmacokinetic Study of Fixed-Dose Co...
# 1  7067711  (9, 8, 2023)  Decline and diversity in Swedish seas: Environ...
#
#                                              Authors Non_Author_Contributors  \
# 0  [Sanela Tarabar, Debra Kelsh, Bradley Vince, R...                    None
# 1  [Susanna Lidström, Sverker Sörlin, Henrik Sved...                    None
#
#                                             Abstract  \
# 0  \nSECTION: Introduction:\n\nA fixed-dose combi...
# 1  \nBefore the mid-twentieth century, there was ...
#
#                                                 Body  \
# 0  \nSECTION: Key Points:\n\n\n\nSECTION: Introdu...
# 1  \nSECTION: Introduction: A narrative of declin...
#
#                                           Journal_ID Journal_Title  \
# 0  {'nlm-ta': 'Drugs R D', 'iso-abbrev': 'Drugs R...  Drugs in R&D
# 1         {'nlm-ta': 'Ambio', 'iso-abbrev': 'Ambio'}         Ambio
#
#                                          ISSN  ...     License  \
# 0  {'ppub': '1174-5886', 'epub': '1179-6901'}  ...  OpenAccess
# 1  {'ppub': '0044-7447', 'epub': '1654-7209'}  ...  OpenAccess
#
#                                              Funding  \
# 0                       [Pfizer Consumer Healthcare]
# 1  [The Swedish Research Council, European Resear...
#
#                                             Footnote  \
# 0  The authors David E. Kellstein, Suzanne Meeves...
# 1  Publisher's Note - Springer Nature remains neu...
#
#                                     Acknowledgements  \
# 0  [Acknowledgements \n       Medical writing sup...
# 1  [Acknowledgements \n       Open access funding...
#
#                                                Notes  \
# 0  [Title: Author Contributions\nStudy design: Al...
# 1                                                 []
#
#                                          Custom_Meta  \
# 0  {'issue-copyright-statement': '© The Author(s)...
# 1  {'issue-copyright-statement': '© Royal Swedish...
#
#                                              Ref_Map  \
# 0  {0:                                           ...
# 1  {0: 'Awebro, K. 2008. Ett bottennapp för Sveri...
#
#                                            Citations  \
# 0  [Authors: ['A Dickman']; Title: Choosing over-...
# 1  [Authors: ['E Hagen', 'R Feistel']; Title: Cli...
#
#                                               Tables  \
# 0  [<table border="1" class="dataframe">\n  <thea...
# 1                                                 []
#
#                                              Figures
# 0  [{'Label': 'Fig. 1', 'Caption': 'Median plasma...
# 1                                                 []
#
# [2 rows x 31 columns]

# %%
pset2.visualize()
# Out:
# MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.

# %%
pset = paperSet.from_search(EMAIL, term = "plants AND nitrogen", retmax = 11)
# Out:
# Generating paperSet from search (This can take a while due to PMC HTTP Request Limitations!)...
# An exception occurred: Extra content at the end of the document, line 1, column 126 (<string>, line 1)
# pubmedHTTPError: Unable to retrieve PMCID 10484656 from PMC. May be due to HTTP traffic or broken XML formatting, try again later if the former.
# Done generating paperSet!

# %%
pset.visualize()
# Out:
# MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
