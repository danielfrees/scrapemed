# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.insert(0, "../../scrapemed")

import scrapemed.paper as paper
import scrapemed.scrape as scrape
from scrapemed.paperSet import paperSet
import pandas as pd
import lxml
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# True

# %%
EMAIL = os.getenv("PMC_EMAIL")
pset = paperSet.from_search(EMAIL, term = "brain[ti] AND surgery[ti]", retmax = 11)
# Out:
# Generating paperSet from search (This can take a while due to PMC HTTP Request Limitations!)...
# Done generating paperSet!

# %%
pset[0].title
# Out:
# 'Usefulness of the N-Terminal of the Prohormone Brain Natriuretic Peptide in Predicting Acute Kidney Injury Requiring Renal Replacement Therapy in Patients Undergoing Heart Valve Surgery'

# %%
pset.add_pmcids(pmcids= [7067710, 7067711], email = EMAIL)
# Out:
# 2

# %%
pset.df
# Out:
#        PMCID  Last_Updated                                              Title  \
# 0   10744829  (1, 5, 2024)  Usefulness of the N-Terminal of the Prohormone...
# 1   10711149  (1, 5, 2024)  The advantages of general anesthesia subthalam...
# 2   10710589  (1, 5, 2024)  10037-SPE-3 APPROACH TO SAFE AND RELIABLE BRAI...
# 3   10698442  (1, 5, 2024)  Effects of ulinastatin therapy in deep vein th...
# 4   10692402  (1, 5, 2024)  Cooling for cerebral protection during brain s...
# 5   10749855  (1, 5, 2024)  Simplifying the Technique of Awake Brain Surge...
# 6   10742002  (1, 5, 2024)   Neuroimaging of Brain Tumor Surgery and Epilepsy
# 7   10714222  (1, 5, 2024)  Outcomes of traumatic brain injury patients wi...
# 8   10681104  (1, 5, 2024)  Video game experience affects performance, cog...
# 9   10680896  (1, 5, 2024)  \nFully automatic segmentation of brain lacuna...
# 10  10676679  (1, 5, 2024)  Bariatric Surgery and Gut-Brain-Axis Driven Al...
# 11   7067710  (1, 5, 2024)  Phase I Pharmacokinetic Study of Fixed-Dose Co...
# 12   7067711  (1, 5, 2024)  Decline and diversity in Swedish seas: Environ...
#
#                                               Authors Non_Author_Contributors  \
# 0               [Piotr Duchnowski, Witold Śmigielski]   [Aron-Frederik Popov]
# 1                           [Cunbao Guo, Taihong Gao]                    None
# 2   [Yusuke Kobayashi, Yosuke Satou, Yuta Kawauchi...                    None
# 3   [Yun-Na Tao, Qian Han, Wei Jiao, Li-Kun Yang, ...                    None
# 4   [Imelda M Galvin, Ron Levy, J. Gordon Boyd, An...             [None None]
# 5   [Dilshod Mukhammadvalievich Mamadaliev, Gayrat...                    None
# 6                                      [Takehiro Uda]                    None
# 7   [Sengua Koipapi, Blandina T. Mmbaga, Kondo Chi...                    None
# 8                   [Hasan Onur Keleş, Ahmet Omurtag]                    None
# 9   [Raphael Fernandes Casseb, Brunno Machado de C...                    None
# 10  [Emma Custers, Ayla Franco, Amanda Johanne Kil...                    None
# 11  [Sanela Tarabar, Debra Kelsh, Bradley Vince, R...                    None
# 12  [Susanna Lidström, Sverker Sörlin, Henrik Sved...                    None
#
#                                              Abstract  \
# 0   \nBackground and Objectives: By definition, ac...
# 1   \nSECTION: Background and Aims:\n\nWith advanc...
# 2   \nIn primary brain tumors, the complexity of E...
# 3   \nSECTION: BACKGROUND:\n\nVenous thromboemboli...
# 4   \nSECTION: Background:\n\nPatients undergoing ...
# 5   \nCurrently, awake craniotomy (AC) is one of t...
# 6
# 7   \nSECTION: Background:\n\nTraumatic brain inju...
# 8   \nSECTION: Objectives:\n\nVideo games can be a...
# 9   \nThe rapid and constant development of deep l...
# 10  \nObesity is associated with systemic inflamma...
# 11  \nSECTION: Introduction:\n\nA fixed-dose combi...
# 12  \nBefore the mid-twentieth century, there was ...
#
#                                                  Body  \
# 0   \nSECTION: 1. Introduction:\n\nAccording to th...
# 1   \nSECTION: INTRODUCTION:\n\nSubthalamic nucleu...
# 2
# 3   \nCore Tip: Venous thromboembolism (VTE) is a ...
# 4
# 5   \nSECTION: Introduction:\n\n“Arise! Awake! And...
# 6   \nTo make the best clinical judgements, surgeo...
# 7   \nSECTION: Introduction:\n\nTraumatic brain in...
# 8
# 9
# 10  \nSECTION: Introduction:\n\nObesity is a major...
# 11  \nSECTION: Key Points:\n\n\n\nSECTION: Introdu...
# 12  \nSECTION: Introduction: A narrative of declin...
#
#                                            Journal_ID  \
# 0   {'nlm-ta': 'Medicina (Kaunas)', 'iso-abbrev': ...
# 1   {'nlm-ta': 'Health Sci Rep', 'iso-abbrev': 'He...
# 2   {'nlm-ta': 'Neurooncol Adv', 'iso-abbrev': 'Ne...
# 3   {'nlm-ta': 'World J Clin Cases', 'publisher-id...
# 4   {'nlm-ta': 'Cochrane Database Syst Rev', 'iso-...
# 5   {'nlm-ta': 'Asian J Neurosurg', 'iso-abbrev': ...
# 6   {'nlm-ta': 'Brain Sci', 'iso-abbrev': 'Brain S...
# 7   {'nlm-ta': 'World Neurosurg X', 'iso-abbrev': ...
# 8   {'nlm-ta': 'Turk J Surg', 'iso-abbrev': 'Turk ...
# 9    {'nlm-ta': 'medRxiv', 'publisher-id': 'MEDRXIV'}
# 10  {'nlm-ta': 'J Inflamm Res', 'iso-abbrev': 'J I...
# 11  {'nlm-ta': 'Drugs R D', 'iso-abbrev': 'Drugs R...
# 12         {'nlm-ta': 'Ambio', 'iso-abbrev': 'Ambio'}
#
#                                   Journal_Title  \
# 0                                      Medicina
# 1                        Health Science Reports
# 2                       Neuro-Oncology Advances
# 3               World Journal of Clinical Cases
# 4   The Cochrane Database of Systematic Reviews
# 5                 Asian Journal of Neurosurgery
# 6                                Brain Sciences
# 7                         World Neurosurgery: X
# 8                    Turkish Journal of Surgery
# 9                                       medRxiv
# 10             Journal of Inflammation Research
# 11                                 Drugs in R&D
# 12                                        Ambio
#
#                                           ISSN  ...        License  \
# 0   {'ppub': '1010-660X', 'epub': '1648-9144'}  ...  Not Specified
# 1                        {'epub': '2398-8835'}  ...  Not Specified
# 2                        {'epub': '2632-2498'}  ...  Not Specified
# 3                        {'epub': '2307-8960'}  ...  Not Specified
# 4                        {'epub': '1469-493X'}  ...           None
# 5   {'ppub': '1793-5482', 'epub': '2248-9614'}  ...  Not Specified
# 6                        {'epub': '2076-3425'}  ...  Not Specified
# 7                        {'epub': '2590-1397'}  ...  Not Specified
# 8   {'ppub': '2564-6850', 'epub': '2564-7032'}  ...           None
# 9                                           {}  ...           None
# 10                       {'epub': '1178-7031'}  ...  Not Specified
# 11  {'ppub': '1174-5886', 'epub': '1179-6901'}  ...     OpenAccess
# 12  {'ppub': '0044-7447', 'epub': '1654-7209'}  ...     OpenAccess
#
#                                               Funding  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                       [Pfizer Consumer Healthcare]
# 12  [The Swedish Research Council, European Resear...
#
#                                              Footnote  \
# 0   Disclaimer/Publisher’s Note: The statements, o...
# 1                                                None
# 2                                                None
# 3   Institutional review board statement: The meth...
# 4                                                None
# 5   Conflict of Interest None declared. - Activiti...
# 6   Disclaimer/Publisher’s Note: The statements, o...
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11  The authors David E. Kellstein, Suzanne Meeves...
# 12  Publisher's Note - Springer Nature remains neu...
#
#                                      Acknowledgements  \
# 0                                                  []
# 1   [ACKNOWLEDGMENTS \n       This work was suppor...
# 2                                                  []
# 3                                                  []
# 4                                                  []
# 5   [Acknowledgements \n       We acknowledge our ...
# 6   [Acknowledgments \n       We thank all the aut...
# 7   [Acknowledgements \n       I want to thank Tum...
# 8                                                  []
# 9                                                  []
# 10                                                 []
# 11  [Acknowledgements \n       Medical writing sup...
# 12  [Acknowledgements \n       Open access funding...
#
#                                                 Notes  \
# 0   [Title: Author Contributions\nConceptualizatio...
# 1                                              [\n\n]
# 2                                                  []
# 3                                                  []
# 4   [New search for studies and content updated (n...
# 5                                                  []
# 6   [Title: Conflicts of Interest\nThe author decl...
# 7                                                  []
# 8                                                  []
# 9                                                  []
# 10                                                 []
# 11  [Title: Author Contributions\nStudy design: Al...
# 12                                                 []
#
#                                           Custom_Meta  \
# 0                                                None
# 1   {'source-schema-version-number': '2.0', 'cover...
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11  {'issue-copyright-statement': '© The Author(s)...
# 12  {'issue-copyright-statement': '© Royal Swedish...
#
#                                               Ref_Map  \
# 0   {0: {'Authors': ['S. Verma', 'J.A. Kellum'], '...
# 1   {0: '
# ', 1: '
# ', 2: '
# ', 3: '
# ', 4: '
# ', 5: '
# ...
# 2                                                  {}
# 3   {0: {'Authors': ['JM Wong', 'JR Panchmatia', '...
# 4                                                  {}
# 5   {0: {'Authors': ['K Motomura', 'M Fujii', 'S M...
# 6   {0: {'Authors': ['N.G. Candy', 'C. Ovenden', '...
# 7   {0: {'Authors': ['C.A. Staton', 'D. Msilanga',...
# 8                                                  {}
# 9                                                  {}
# 10  {0: '. ', 1: '. ', 2: '. ', 3: '. ', 4: '. ', ...
# 11  {0:                                           ...
# 12  {0: 'Awebro, K. 2008. Ett bottennapp för Sveri...
#
#                                             Citations  \
# 0   [Authors: ['S. Verma', 'J.A. Kellum']; Title: ...
# 1                                                  []
# 2                                                  []
# 3   [Authors: ['JM Wong', 'JR Panchmatia', 'JE Zie...
# 4                                                  []
# 5   [Authors: ['K Motomura', 'M Fujii', 'S Maesawa...
# 6   [Authors: ['N.G. Candy', 'C. Ovenden', 'A.K. J...
# 7   [Authors: ['C.A. Staton', 'D. Msilanga', 'G. K...
# 8                                                  []
# 9                                                  []
# 10                                                 []
# 11  [Authors: ['A Dickman']; Title: Choosing over-...
# 12  [Authors: ['E Hagen', 'R Feistel']; Title: Cli...
#
#                                                Tables  \
# 0   [<style type="text/css">\n</style>\n<table id=...
# 1   [<style type="text/css">\n</style>\n<table id=...
# 2                                                  []
# 3   [<style type="text/css">\n</style>\n<table id=...
# 4                                                  []
# 5                                                  []
# 6                                                  []
# 7   [<style type="text/css">\n</style>\n<table id=...
# 8                                                  []
# 9                                                  []
# 10  [<style type="text/css">\n</style>\n<table id=...
# 11  [<table border="1" class="dataframe">\n  <thea...
# 12                                                 []
#
#                                               Figures
# 0   [{'Label': 'Figure 1', 'Caption': '
#         Ar...
# 1   [{'Label': 'Figure 1', 'Caption': '
#           ...
# 2                                                  []
# 3   [{'Label': 'Figure 1', 'Caption': '
#           ...
# 4                                                  []
# 5   [{'Label': 'Fig. 1', 'Caption': '
#             ...
# 6                                                  []
# 7   [{'Label': 'Fig. 1', 'Caption': 'Symptoms at p...
# 8                                                  []
# 9                                                  []
# 10  [{'Label': 'Figure 1', 'Caption': 'Changes in ...
# 11  [{'Label': 'Fig. 1', 'Caption': 'Median plasma...
# 12                                                 []
#
# [13 rows x 31 columns]

# %%
pset.df.columns
# Out:
# Index(['PMCID', 'Last_Updated', 'Title', 'Authors', 'Non_Author_Contributors',
#        'Abstract', 'Body', 'Journal_ID', 'Journal_Title', 'ISSN',
#        'Publisher_Name', 'Publisher_Location', 'Article_ID', 'Article_Types',
#        'Article_Categories', 'Published_Date', 'Volume', 'Issue', 'First_Page',
#        'Last_Page', 'Copyright', 'License', 'Funding', 'Footnote',
#        'Acknowledgements', 'Notes', 'Custom_Meta', 'Ref_Map', 'Citations',
#        'Tables', 'Figures'],
#       dtype='object')

# %%
pset.visualize()

# %%
pset2 = paperSet.from_pmcid_list([7067710, 7067711], EMAIL)
# Out:
# Generating paperSet from PMCID list (This can take a while due to PMC HTTP Request Limitations!)...
# Done generating paperSet!

# %%
pset2.df
# Out:
#      PMCID   Last_Updated                                              Title  \
# 0  7067710  (9, 19, 2023)  Phase I Pharmacokinetic Study of Fixed-Dose Co...
# 1  7067711  (9, 19, 2023)  Decline and diversity in Swedish seas: Environ...
#
#                                              Authors Non_Author_Contributors  \
# 0  [Sanela Tarabar, Debra Kelsh, Bradley Vince, R...                    None
# 1  [Susanna Lidström, Sverker Sörlin, Henrik Sved...                    None
#
#                                             Abstract  \
# 0  \nSECTION: Introduction:\n\nA fixed-dose combi...
# 1  \nBefore the mid-twentieth century, there was ...
#
#                                                 Body  \
# 0  \nSECTION: Key Points:\n\n\n\nSECTION: Introdu...
# 1  \nSECTION: Introduction: A narrative of declin...
#
#                                           Journal_ID Journal_Title  \
# 0  {'nlm-ta': 'Drugs R D', 'iso-abbrev': 'Drugs R...  Drugs in R&D
# 1         {'nlm-ta': 'Ambio', 'iso-abbrev': 'Ambio'}         Ambio
#
#                                          ISSN  ...     License  \
# 0  {'ppub': '1174-5886', 'epub': '1179-6901'}  ...  OpenAccess
# 1  {'ppub': '0044-7447', 'epub': '1654-7209'}  ...  OpenAccess
#
#                                              Funding  \
# 0                       [Pfizer Consumer Healthcare]
# 1  [The Swedish Research Council, European Resear...
#
#                                             Footnote  \
# 0  The authors David E. Kellstein, Suzanne Meeves...
# 1  Publisher's Note - Springer Nature remains neu...
#
#                                     Acknowledgements  \
# 0  [Acknowledgements \n       Medical writing sup...
# 1  [Acknowledgements \n       Open access funding...
#
#                                                Notes  \
# 0  [Title: Author Contributions\nStudy design: Al...
# 1                                                 []
#
#                                          Custom_Meta  \
# 0  {'issue-copyright-statement': '© The Author(s)...
# 1  {'issue-copyright-statement': '© Royal Swedish...
#
#                                              Ref_Map  \
# 0  {0:                                           ...
# 1  {0: 'Awebro, K. 2008. Ett bottennapp för Sveri...
#
#                                            Citations  \
# 0  [Authors: ['A Dickman']; Title: Choosing over-...
# 1  [Authors: ['E Hagen', 'R Feistel']; Title: Cli...
#
#                                               Tables  \
# 0  [<table border="1" class="dataframe">\n  <thea...
# 1                                                 []
#
#                                              Figures
# 0  [{'Label': 'Fig. 1', 'Caption': 'Median plasma...
# 1                                                 []
#
# [2 rows x 31 columns]

# %%
pset2.visualize()
# Out:
# MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.

# %%
pset = paperSet.from_search(EMAIL, term = "plants AND nitrogen", retmax = 11)
# Out:
# Generating paperSet from search (This can take a while due to PMC HTTP Request Limitations!)...
# Done generating paperSet!

# %%
pset.visualize()
# Out:
# MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
